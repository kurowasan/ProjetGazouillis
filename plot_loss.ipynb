# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# file_path = "results/exp_002/log.txt"
file_pathes = ['results/exp_001/log.txt','results/exp_002/log.txt','results/exp_003/log.txt','results/exp_004/log.txt',]

plt.figure()
for file_path in file_pathes:
    times = []
    losses = []

    f = open(file_path,'r')
    for line in f:
        arr = line.split()
        if arr[0]=="Epoch":
            losses.append(float(arr[11]))
            times.append(int(arr[3]))

    plt.plot(np.cumsum(np.array(times)),losses)
    print "minimum loss : ",np.min(losses)
# plt.xlim(0,50000)
# Out:
#  minimum loss :  1.7337
# minimum loss :  1.7289
# minimum loss :  1.7439
# minimum loss :  1.7443

# %%
plt.xlim(0,50000)
# Out:
# (0, 50000)
